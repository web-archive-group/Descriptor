# %%
# Install the igraph library
library(igraph)

# %%
# Helper function for getting warcbase data into igraph
processFile = function(filepath) {
  con = file(filepath, "r")
  line = readLines(con)
  line <- as.data.frame(do.call(rbind, (strsplit(gsub('\\(|\\)', '', line), ','))), stringsAsFactors=FALSE)
  names(line) = c("date", "from", "to", "weight")
  return (line)
  close(con)
}

# %%
# Grab the data files
filepath = '~/data/links/'
file = 'ALBERTA_energy_environment'
suffix = '-links.txt'

savesuffix = '.graphml'
savepath = '~/data/graphml/'

filename = paste0(filepath, file, suffix)
savename = paste0(savepath, file, savesuffix)

graph_file <- graph.data.frame(unique(processFile(filename)[c("from", "to")]), directed=TRUE)
graph_file <- simplify(graph_file)

print(graph_file)
print(V(graph_file)$name)
# Out:
# IGRAPH DN-- 414 411 --
# + attr: name (v/c)
# + edges (vertex names):
#  [1] cepa.com->capp.ca              cepa.com->plainsmidstream.com
#  [3] cepa.com->youtube.com          cepa.com->ducks.ca
#  [5] cepa.com->enform.ca            cepa.com->nrcan.gc.ca
#  [7] cepa.com->shop.csa.ca          cepa.com->wcss.ab.ca
#  [9] cepa.com->albertaonecall.com   cepa.com->canadiancga.com
# [11] cepa.com->accesspipeline.com   cepa.com->schulich.ucalgary.ca
# [13] cepa.com->statcan.gc.ca        cepa.com->issuu.com
# [15] cepa.com->fortisbc.com         cepa.com->neb-one.gc.ca
# + ... omitted several edges
#   [1] "cepa.com"
#   [2] "ceaa-acee.gc.ca"
#   [3] "capp.ca"
#   [4] "plainsmidstream.com"
#   [5] "energy.ca"
#   [6] "pm.gc.ca"
#   [7] "greenpeace.org"
#   [8] "youtube.com"
#   [9] "npa.gc.ca"
#  [10] "dublincore.org"
#  [11] "ducks.ca"
#  [12] "enform.ca"
#  [13] "state.gov"
#  [14] "smu.ca"
#  [15] "lactualite.com"
#  [16] "huffingtonpost.com"
#  [17] "plus.google.com"
#  [18] "accounts.google.com"
#  [19] "nrcan.gc.ca"
#  [20] "ottawacitizen.com"
#  [21] "earthquakescanada.nrcan.gc.ca"
#  [22] "seismescanada.rncan.gc.ca"
#  [23] "questerre.com"
#  [24] "albertaventure.com"
#  [25] "whitehouse.gov"
#  [26] "dvn.com"
#  [27] "2014.globeseries.com"
#  [28] "devonenergy.com"
#  [29] "shop.csa.ca"
#  [30] "info-ex.com"
#  [31] "blog.transcanada.com"
#  [32] "telegraph.co.uk"
#  [33] "arcresources.com"
#  [34] "prci.org"
#  [35] "simpcw.com"
#  [36] "laricinaenergy.com"
#  [37] "rbsomerville.com"
#  [38] "internationalresourcejournal.com"
#  [39] "wcss.ab.ca"
#  [40] "northerngateway.ca"
#  [41] "parexresources.com"
#  [42] "usoilsandsinc.com"
#  [43] "albertaonecall.com"
#  [44] "canadiancga.com"
#  [45] "accesspipeline.com"
#  [46] "ge.com"
#  [47] "schulich.ucalgary.ca"
#  [48] "conocophillips.ca"
#  [49] "congress.gov"
#  [50] "rethinkrethinkalberta.blogspot.com"
#  [51] "peanutbureau.ca"
#  [52] "shell.ca"
#  [53] "bonavistaenergy.com"
#  [54] "canadasnaturalgas.ca"
#  [55] "swenergy.ca"
#  [56] "zargon.ca"
#  [57] "imperialoil.ca"
#  [58] "nait.ca"
#  [59] "statcan.gc.ca"
#  [60] "qrinc.com"
#  [61] "issuu.com"
#  [62] "dal.ca"
#  [63] "birchcliffenergy.com"
#  [64] "cooncome.ca"
#  [65] "thecptc.ca"
#  [66] "tourmalineoil.com"
#  [67] "envirotechaviation.com"
#  [68] "calgaryherald.com"
#  [69] "huskyenergy.com"
#  [70] "fortisbc.com"
#  [71] "thecanadianencyclopedia.ca"
#  [72] "nucleus.com"
#  [73] "neb-one.gc.ca"
#  [74] "manitoba.ca"
#  [75] "atcopipelines.com"
#  [76] "archive.canola-council.org"
#  [77] "internationalpipelineconference.com"
#  [78] "cappscotia.com"
#  [79] "wordpress.org"
#  [80] "cloudflare.com"
#  [81] "brunswickpipeline.com"
#  [82] "albertatechfutures.ca"
#  [83] "disqus.com"
#  [84] "emeranewbrunswick.com"
#  [85] "alliancepipeline.com"
#  [86] "ubc.ca"
#  [87] "on1call.com"
#  [88] "transmountain.com"
#  [89] "acee-ceaa.gc.ca"
#  [90] "enbridge.com"
#  [91] "pipelineandgasjournal.com"
#  [92] "www1.agric.gov.ab.ca"
#  [93] "edmontonjournal.com"
#  [94] "policyschool.ucalgary.ca"
#  [95] "jquery.com"
#  [96] "appstore.capp.ca"
#  [97] "world-nuclear.org"
#  [98] "pmpl.com"
#  [99] "schema.org"
# [100] "cdnoilsands.com"
# [101] "talisman-energy.com"
# [102] "pennwest.com"
# [103] "businessinsider.com"
# [104] "letskeepcanadamoving.ca"
# [105] "cnrl.com"
# [106] "support.google.com"
# [107] "secure-energy.com"
# [108] "slideshare.net"
# [109] "bp.com"
# [110] "infrastructure.alberta.ca"
# [111] "transcanada.com"
# [112] "longrunexploration.com"
# [113] "w3.org"
# [114] "phmsa.dot.gov"
# [115] "dentons.com"
# [116] "touchstoneexploration.com"
# [117] "canada.gc.ca"
# [118] "indigopipeline.com"
# [119] "worldenergy.org"
# [120] "ic.gc.ca"
# [121] "flickr.com"
# [122] "twitter.com"
# [123] "facebook.com"
# [124] "pitchdigital.com"
# [125] "greenpeace.donorportal.ca"
# [126] "membernet.capp.ca"
# [127] "login.live.com"
# [128] "linkedin.com"
# [129] "thecepafoundation.sharepoint.com"
# [130] "google.com"
# [131] "purl.org"
# [132] "adobe.com"
# [133] "pm.drupal.staging.b.net"
# [134] "statshb.capp.ca"
# [135] "rncan.gc.ca"
# [136] "tbs-sct.gc.ca"
# [137] "laws-lois.justice.gc.ca"
# [138] "dfo-mpo.gc.ca"
# [139] "phx.corporate-ir.net"
# [140] "justice.gc.ca"
# [141] "gazette.gc.ca"
# [142] "pwgsc.gc.ca"
# [143] "ngps.nt.ca"
# [144] "lois-laws.justice.gc.ca"
# [145] "oilsandstoday.ca"
# [146] "bip-pio.qc.ca"
# [147] "laws.justice.gc.ca"
# [148] "apn.gc.ca"
# [149] "youtu.be"
# [150] "recherche-search.gc.ca"
# [151] "my.enform.ca"
# [152] "energycitizens.ca"
# [153] "bit.ly"
# [154] "ucalgary.ca"
# [155] "blogger.com"
# [156] "get.adobe.com"
# [157] "conocophillips.com"
# [158] "mveirb.nt.ca"
# [159] "canadagazette.gc.ca"
# [160] "adaptation.nrcan.gc.ca"
# [161] "atlanticcanadaoffshore.ca"
# [162] "ec.gc.ca"
# [163] "hydroquebec.com"
# [164] "shell.com"
# [165] "centreforenergy.com"
# [166] "ow.ly"
# [167] "jobs-emplois.gc.ca"
# [168] "ceri.ca"
# [169] "collectionscanada.gc.ca"
# [170] "tpsgc.gc.ca"
# [171] "nrcan-rncan.gc.ca"
# [172] "menv.gouv.qc.ca"
# [173] "climatechange.gc.ca"
# [174] "gov.ns.ca"
# [175] "pc.gc.ca"
# [176] "rss-specifications.com"
# [177] "eao.gov.bc.ca"
# [178] "172.20.2.124"
# [179] "addtoany.com"
# [180] "cosia.ca"
# [181] "gatewaypanel.review-examen.gc.ca"
# [182] "nrcb.gov.ab.ca"
# [183] "iap2.org"
# [184] "travel.state.gov"
# [185] "environment.gov.au"
# [186] "unfccc.int"
# [187] "mddep.gouv.qc.ca"
# [188] "csagroup.org"
# [189] "docs.neb-one.gc.ca"
# [190] "sucuri.net"
# [191] "saiea.com"
# [192] "parl.gc.ca"
# [193] "gov.mb.ca"
# [194] "tc.gc.ca"
# [195] "suncor.com"
# [196] "ainc-inac.gc.ca"
# [197] "investors.qrinc.com"
# [198] "ww3.ducks.ca"
# [199] "infrastructure.gc.ca"
# [200] "rsc-src.ca"
# [201] "gnb.ca"
# [202] "cnlopb.nl.ca"
# [203] "acdi-cida.gc.ca"
# [204] "careers.state.gov"
# [205] "actionplan.gc.ca"
# [206] "info.alliance-pipeline.com"
# [207] "neb.gc.ca"
# [208] "go.microsoft.com"
# [209] "scontent.cdninstagram.com"
# [210] "tpsgc-pwgsc.gc.ca"
# [211] "gov.nf.ca"
# [212] "c-ciarn.ca"
# [213] "eub.gov.ab.ca"
# [214] "canadiannaturalgas.ca"
# [215] "canada.ca"
# [216] "clickbeforeyoudig.com"
# [217] "blog.enbridge.com"
# [218] "ccemc.ca"
# [219] "househunting.ca"
# [220] "buyersguide.pipelineandgasjournal.com"
# [221] "gov.pe.ca"
# [222] "agriculture.alberta.ca"
# [223] "sablesbitumineuxmaintenant.ca"
# [224] "cnsc.gc.ca"
# [225] "ercb.ca"
# [226] "oilsandsdevelopers.ca"
# [227] "ptac.org"
# [228] "env.gov.nl.ca"
# [229] "bcogc.ca"
# [230] "conferenceboard.ca"
# [231] "ietf.org"
# [232] "ypacanada.com"
# [233] "roseninspection.net"
# [234] "gov.ab.ca"
# [235] "getprepared.gc.ca"
# [236] "canadasoilsands.ca"
# [237] "jquery.org"
# [238] "preparez-vous.gc.ca"
# [239] "secure3.convio.net"
# [240] "inac.gc.ca"
# [241] "environment.gov.sk.ca"
# [242] "plandaction.gc.ca"
# [243] "iaf.org"
# [244] "oilsands.alberta.ca"
# [245] "make.wordpress.org"
# [246] "greenpeaceblogs.org"
# [247] "consultingcanadians.gc.ca"
# [248] "rwed.gov.nt.ca"
# [249] "wd.gc.ca"
# [250] "suretenucleaire.gc.ca"
# [251] "publications.gc.ca"
# [252] "enr.gov.nt.ca"
# [253] "vcr-mvr.ca"
# [254] "serm.gov.sk.ca"
# [255] "keac-ccek.ca"
# [256] "wlapwww.gov.bc.ca"
# [257] "iaia.org"
# [258] "usgcrp.gov"
# [259] "cics.uvic.ca"
# [260] "www3.gov.ab.ca"
# [261] "sts.gsc.nrcan.gc.ca"
# [262] "thataway.org"
# [263] "capp.pitchdigital.com"
# [264] "ccme.ca"
# [265] "gov.nu.ca"
# [266] "grida.no"
# [267] "recherche.rncan.gc.ca"
# [268] "bape.gouv.qc.ca"
# [269] "canada.com"
# [270] "ewb.ca"
# [271] "scf.rncan.gc.ca"
# [272] "cfs.nrcan.gc.ca"
# [273] "search.nrcan.gc.ca"
# [274] "psc-cfp.gc.ca"
# [275] "talismanenergy.mwnewsroom.com"
# [276] "environment.alberta.ca"
# [277] "ene.gov.on.ca"
# [278] "pennwest.mediaroom.com"
# [279] "oceans.greenpeace.org"
# [280] "cnlopb.ca"
# [281] "community.csagroup.org"
# [282] "aadnc-aandc.gc.ca"
# [283] "aer.ca"
# [284] "agr.ca"
# [285] "historicacanada.ca"
# [286] "careers.conocophillips.com"
# [287] "kindermorgan.com"
# [288] "ipsos-na.com"
# [289] "nativemaps.org"
# [290] "classifieds.ottawacitizen.com"
# [291] "alberta.ca"
# [292] "conservator.ca"
# [293] "aboutpipelinesmap.com"
# [294] "spectraenergy.com"
# [295] "t.co"
# [296] "gbm.scotiabank.com"
# [297] "atco.com"
# [298] "forces.gc.ca"
# [299] "gov.yk.ca"
# [300] "msc.ec.gc.ca"
# [301] "gov.nt.ca"
# [302] "loc.gov"
# [303] "bdc.ca"
# [304] "lois.justice.gc.ca"
# [305] "eca.state.gov"
# [306] "alliance-pipeline.com"
# [307] "environmentyukon.gov.yk.ca"
# [308] "cnrl-careers.com"
# [309] "pembina.com"
# [310] "publiservice.tbs-sct.gc.ca"
# [311] "ea.gov.au"
# [312] "careersinoilandgas.com"
# [313] "mackenziegasproject.com"
# [314] "energyiq.canadiangeographic.ca"
# [315] "aboutpipelines.com"
# [316] "investor.dvn.com"
# [317] "eic.or.jp"
# [318] "cga.ca"
# [319] "mpmo-bggp.gc.ca"
# [320] "diplomacy.state.gov"
# [321] "transgas.com"
# [322] "conama.cl"
# [323] "senate.gov"
# [324] "www-penelope.drec.unilim.fr"
# [325] "sct-tbs.gc.ca"
# [326] "penelope.uni-bremen.de"
# [327] "hmso.gov.uk"
# [328] "venda.com"
# [329] "es.epa.gov"
# [330] "adoption.state.gov"
# [331] "epcc.pref.osaka.jp"
# [332] "ceq.eh.doe.gov"
# [333] "cec.org"
# [334] "ihs.com"
# [335] "planning.detr.gov.uk"
# [336] "contacts.ucalgary.ca"
# [337] "riasinc.com"
# [338] "tnpi.ca"
# [339] "driving.ca"
# [340] "arcresources.mediaroom.com"
# [341] "ubcm.ca"
# [342] "energy.alberta.ca"
# [343] "esdc.gc.ca"
# [344] "contribute.jquery.org"
# [345] "live.huffingtonpost.com"
# [346] "a100.gov.bc.ca"
# [347] "csa.ca"
# [348] "greenwire.greenpeace.org"
# [349] "bgcengineering.com"
# [350] "image.slidesharecdn.com"
# [351] "cagc.ca"
# [352] "talk.transmountain.com"
# [353] "fcc-fac.ca"
# [354] "interpipelinefund.com"
# [355] "unscear.org"
# [356] "fin.gc.ca"
# [357] "classifieds.calgaryherald.com"
# [358] "classifieds.edmontonjournal.com"
# [359] "orphanwell.ca"
# [360] "nccp.ca"
# [361] "eub.ca"
# [362] "nexeninc.com"
# [363] "bclaws.ca"
# [364] "ai-ees.ca"
# [365] "parc.ca"
# [366] "enbridgegas.com"
# [367] "en.wikipedia.org"
# [368] "oilandgascareerinfo.ca"
# [369] "mvlwb.com"
# [370] "gaznaturelcanadien.ca"
# [371] "env.gov.bc.ca"
# [372] "cbc.ca"
# [373] "ocl-cal.gc.ca"
# [374] "unesco.org"
# [375] "syncrude.ca"
# [376] "privcom.gc.ca"
# [377] "cappwww.capp.internal"
# [378] "csrreport.transcanada.com"
# [379] "cnsopb.ns.ca"
# [380] "carleton.ca"
# [381] "qp.gov.sk.ca"
# [382] "longrun.mwnewsroom.com"
# [383] "dfait-maeci.gc.ca"
# [384] "esso.ca"
# [385] "ipcc.ch"
# [386] "alis.alberta.ca"
# [387] "idrc.ca"
# [388] "wise.uwaterloo.ca"
# [389] "caodc.ca"
# [390] "gov.bc.ca"
# [391] "sagegc-gedsgc.tpsgc-pwgsc.gc.ca"
# [392] "iisd.org"
# [393] "ccegj-jbace.ca"
# [394] "acoa.ca"
# [395] "psagency-agencefp.gc.ca"
# [396] "blogs.state.gov"
# [397] "est.gov.on.ca"
# [398] "smallbusiness.albertaventure.com"
# [399] "lobbyistsact.ab.ca"
# [400] "workopolis.com"
# [401] "carbon.cfs.nrcan.gc.ca"
# [402] "ecogeste.gouv.qc.ca"
# [403] "history.state.gov"
# [404] "pmddtc.state.gov"
# [405] "mrn.gouv.qc.ca"
# [406] "ccebj-jbace.ca"
# [407] "bib.schema.org"
# [408] "hrdc-drhc.gc.ca"
# [409] "service.govdelivery.com"
# [410] "polarnet.ca"
# [411] "yosemite.epa.gov"
# [412] "ouranos.ca"
# [413] "www-pub.iaea.org"
# [414] "nuclearsafety.gc.ca"

# %%
# Write the graphml
write.graph (graph_file, savename, format='graphml')

# %%
#Create vectors for strongly connected components, degree etc.
V(graph_file)$s_component <- clusters(graph_file, "strong")$membership
V(graph_file)$w_component <- clusters(graph_file, "weak")$membership
V(graph_file)$indegree <- degree(graph_file, mode="in", loops=FALSE)
V(graph_file)$outdegree <- degree(graph_file, mode="out", loops=FALSE)
V(graph_file)$degree <- degree(graph_file, loops=FALSE)

#print(V(graph_file)$name)
 
dist_component_id <- which(clusters(graph_file, "strong")$csize == max(clusters(graph_file, "strong")$csize))
weak_component_id <- which(clusters(graph_file, "weak")$csize == max(clusters(graph_file, "weak")$csize))

strongly_connected_graph <- induced_subgraph(graph_file, which(V(graph_file)$s_component == dist_component_id))
weakly_connected_graph <- induced_subgraph(graph_file, which(V(graph_file)$w_component == weak_component_id))

#  It may not make sense to plot the full graph if it is too large.
#  In this case, we should plot a large component.  In extreme cases,
#  We can plot just the strongly connected component.

full <- graph_file
weak <- weakly_connected_graph
strong <- strongly_connected_graph

#  Change graph_plot_name to whichever of the above you'd like to plot.

graph_plot_name <- full
V(graph_plot_name)$indegree <- degree(graph_plot_name, mode="in", loops=FALSE)
V(graph_plot_name)$outdegree <- degree(graph_plot_name, mode="out", loops=FALSE)
V(graph_plot_name)$degree <- degree(graph_plot_name, loops=FALSE)
avg_indegree <- mean(V(graph_plot_name)$indegree)
avg_outdegree <- mean(V(graph_plot_name)$outdegree)
avg_degree <- mean(V(graph_plot_name)$degree)

print (paste("Average In-degree:", avg_indegree))
print (paste("Average Out-degree:", avg_outdegree))
print (paste("Average Degree:", avg_degree))

V(graph_plot_name)$relevant <- V(graph_plot_name)$degree > avg_degree + 5
V(graph_plot_name)$rlabel[which(V(graph_plot_name)$relevant == TRUE)] <- V(graph_plot_name)$name[which(V(graph_plot_name)$relevant == TRUE)]
V(graph_plot_name)$wtc <- membership(cluster_edge_betweenness(graph_plot_name))
# Out:
# [1] "Average In-degree: 0.992753623188406"
# [1] "Average Out-degree: 0.992753623188406"
# [1] "Average Degree: 1.98550724637681"
# Warning message in vattrs[[name]][index] <- value:
# “number of items to replace is not a multiple of replacement length”

# %%
mems <- V(graph_plot_name)$wtc
colors <- rainbow(max(mems))

# R plots have a variety of layouts that you can choose from.
# cut and paste any of these into the "layout =" section to change the layout.
# "layout_nicely" is a good generic layout in most cases.

#  layout_nicely(graph_plot_name)
#  layout_with_sugiyama(graph_plot_name)
#  layout_as_tree(graph_plot_name)
#  layout_in_circle(graph_plot_name)
#  layout_on_grid(graph_plot_name)
#  layout_on_sphere(graph_plot_name)
#  layout_with_lgl(graph_plot_name)
#  layout_with_fr(graph_plot_name)

layout = layout_with_fr(graph_plot_name)


plot(graph_plot_name, 
     layout=layout, 
     vertex.size=log(V(graph_plot_name)$degree)*5, 
     vertex.label=V(graph_plot_name)$rlabel, 
     vertex.color=colors[mems],
     vertex.frame.color = "black",
     vertex.label.color="black", 
     vertex.label.font="",
     vertex.label.cex=1,
     vertex.label.dist=0,
     vertex.shape = "circle", # can be “circle”, “square”, “csquare”, 
       #“rectangle”, “crectangle”, “vrectangle”, “pie”, ‘sphere’, and “none”
     edge.width=0.1, 
     edge.arrow.size=0.2, 
     edge.arrow.width=1,
     edge.lty=1,  #0 and “blank” mean no edges, 
     #1 and “solid” are for solid lines, the other possible values are: 
     #2 (“dashed”), 3 (“dotted”), 4 (“dotdash”), 5 (“longdash”), 6 (“twodash”)
    )
# Out:
# Error in i.parse.plot.params(graph, list(...)): Unknown plot parameters: label.degree
# Traceback:
#
# 1. plot(graph_plot_name, layout = layout, vertex.size = log(V(graph_plot_name)$degree) *
#  .     5, vertex.label = V(graph_plot_name)$rlabel, vertex.color = colors[mems],
#  .     vertex.frame.color = "black", vertex.label.color = "black",
#  .     vertex.label.font = "", vertex.label.cex = 1, vertex.label.dist = 0,
#  .     label.degree = -pi/4, vertex.shape = "circle", edge.width = 0.1,
#  .     edge.arrow.size = 0.2, edge.arrow.width = 1, edge.lty = 1,
#  .     )
# 2. plot.igraph(graph_plot_name, layout = layout, vertex.size = log(V(graph_plot_name)$degree) *
#  .     5, vertex.label = V(graph_plot_name)$rlabel, vertex.color = colors[mems],
#  .     vertex.frame.color = "black", vertex.label.color = "black",
#  .     vertex.label.font = "", vertex.label.cex = 1, vertex.label.dist = 0,
#  .     label.degree = -pi/4, vertex.shape = "circle", edge.width = 0.1,
#  .     edge.arrow.size = 0.2, edge.arrow.width = 1, edge.lty = 1,
#  .     )
# 3. i.parse.plot.params(graph, list(...))
# 4. stop("Unknown plot parameters: ", paste(sep = ", ", collapse = ", ",
#  .     names(p[["plot"]])[mis]))
